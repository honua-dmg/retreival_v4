# %% [markdown]
# # Optimising our graphs

# %%
import csv
import os

# %%
filepath = 'test5.csv'
if os.path.exists(filepath)==False:
    print('yeehaw')
else:
    print('beebaw')
# Out:
# beebaw

# %%
with open('test5.csv','w') as f:
    writer = csv.DictWriter(f,['a','b'])
    writer.writeheader()

# %%
import Backtest
uno = Backtest.SingleavgParser('data/NSE/BAJFINANCE/symbol-2024-12-30.csv','data/NSE/BAJFINANCE/depth-2024-12-30.csv',"NSE:BAJFINANCE")
uno.graph()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import Backtest
#       2 uno = Backtest.SingleavgParser('data/NSE/BAJFINANCE/symbol-2024-12-30.csv','data/NSE/BAJFINANCE/depth-2024-12-30.csv',"NSE:BAJFINANCE")
# ----> 3 uno.graph()
#
# File ~/programming/STONKS/retreival_v4/Backtest.py:182, in SingleavgParser.graph(self)
#     180 # Enter data update loop
#     181 while self.r.get("end") != b"true":
# --> 182     update_data()  # Fetch and update data only for the current stock
#     183     update_plot()  # Update the plot with the current stock data
#     184     plt.pause(0.005)  # Allow for real-time interaction
#
# File ~/programming/STONKS/retreival_v4/Backtest.py:151, in SingleavgParser.graph.<locals>.update_data()
#     149 # Only fetch data for the current stock
#     150 stock_name = stonksList[current_index]
# --> 151 data = avg_r.xread({stock_name + "-GRAPH": "$"}, block=100)
#     153 if not data:
#     154     return
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/commands/core.py:3977, in StreamCommands.xread(self, streams, count, block)
#    3975 pieces.extend(keys)
#    3976 pieces.extend(values)
# -> 3977 return self.execute_command("XREAD", *pieces, keys=keys)
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/client.py:559, in Redis.execute_command(self, *args, **options)
#     558 def execute_command(self, *args, **options):
# --> 559     return self._execute_command(*args, **options)
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/client.py:567, in Redis._execute_command(self, *args, **options)
#     565 conn = self.connection or pool.get_connection(command_name, **options)
#     566 try:
# --> 567     return conn.retry.call_with_retry(
#     568         lambda: self._send_command_parse_response(
#     569             conn, command_name, *args, **options
#     570         ),
#     571         lambda error: self._disconnect_raise(conn, error),
#     572     )
#     573 finally:
#     574     if not self.connection:
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/retry.py:62, in Retry.call_with_retry(self, do, fail)
#      60 while True:
#      61     try:
# ---> 62         return do()
#      63     except self._supported_errors as error:
#      64         failures += 1
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/client.py:568, in Redis._execute_command.<locals>.<lambda>()
#     565 conn = self.connection or pool.get_connection(command_name, **options)
#     566 try:
#     567     return conn.retry.call_with_retry(
# --> 568         lambda: self._send_command_parse_response(
#     569             conn, command_name, *args, **options
#     570         ),
#     571         lambda error: self._disconnect_raise(conn, error),
#     572     )
#     573 finally:
#     574     if not self.connection:
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/client.py:542, in Redis._send_command_parse_response(self, conn, command_name, *args, **options)
#     538 """
#     539 Send a command and parse the response
#     540 """
#     541 conn.send_command(*args, **options)
# --> 542 return self.parse_response(conn, command_name, **options)
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/client.py:584, in Redis.parse_response(self, connection, command_name, **options)
#     582         options.pop(NEVER_DECODE)
#     583     else:
# --> 584         response = connection.read_response()
#     585 except ResponseError:
#     586     if EMPTY_RESPONSE in options:
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/connection.py:592, in AbstractConnection.read_response(self, disable_decoding, disconnect_on_error, push_request)
#     588         response = self._parser.read_response(
#     589             disable_decoding=disable_decoding, push_request=push_request
#     590         )
#     591     else:
# --> 592         response = self._parser.read_response(disable_decoding=disable_decoding)
#     593 except socket.timeout:
#     594     if disconnect_on_error:
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/_parsers/resp2.py:15, in _RESP2Parser.read_response(self, disable_decoding)
#      13 pos = self._buffer.get_pos() if self._buffer else None
#      14 try:
# ---> 15     result = self._read_response(disable_decoding=disable_decoding)
#      16 except BaseException:
#      17     if self._buffer:
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/_parsers/resp2.py:25, in _RESP2Parser._read_response(self, disable_decoding)
#      24 def _read_response(self, disable_decoding=False):
# ---> 25     raw = self._buffer.readline()
#      26     if not raw:
#      27         raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/_parsers/socket.py:115, in SocketBuffer.readline(self)
#     112 data = buf.readline()
#     113 while not data.endswith(SYM_CRLF):
#     114     # there's more data in the socket that we need
# --> 115     self._read_from_socket()
#     116     data += buf.readline()
#     118 return data[:-2]
#
# File ~/programming/STONKS/retreival_v4/.venv/lib/python3.11/site-packages/redis/_parsers/socket.py:65, in SocketBuffer._read_from_socket(self, length, timeout, raise_on_timeout)
#      63 try:
#      64     while True:
# ---> 65         data = self._sock.recv(socket_read_size)
#      66         # an empty string indicates the server shutdown the socket
#      67         if isinstance(data, bytes) and len(data) == 0:
#
# KeyboardInterrupt:
