# %%
import authToken
import Main
import wbsoc
import redis
r = redis.Redis(host="localhost",port="6379",db=0)
r.flushall()
# Out:
# True

# %%
token = authToken.AutoLogin().get_access_token()
# Out:
# no neeed to validate :)
# auth_code obtained!
# 200
# ********************************************************************************
# success

# %%
token ='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....Se39ICFJ5AK6fy0arzCkjjUWIMeHpRCZs6UkQ3S_WjE'

# %%
Main.threadripper(token,True)
# Out:
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# connection opened
# reestablished connection
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# connection opened
# reestablished connection
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# ...

# %% [markdown]
# # TESTING

# %%
connection = wbsoc.Symbol(r,token,True)

# %%
connection.connect()
# Out:
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# connection opened
# reestablished connection
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'ltp': 6543.2, 'vol_traded_today': 6025, 'last_traded_time': 1735293599, 'exch_feed_time': 1735325247, 'bid_size': 0, 'ask_size': 0, 'bid_price': 0.0, 'ask_price': 0.0, 'last_traded_qty': 2, 'tot_buy_qty': 0, 'tot_sell_qty': 0, 'avg_trade_price': 6634.11, 'low_price': 6523.55, 'high_price': 6762.35, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 6714.8, 'prev_close_price': 6543.2, 'type': 'sf', 'symbol': 'BSE:SIEMENS-A', 'ch': 0.0, 'chp': 0.0}
# ...

# %%
connection.close()

# %%
connection.fyers.__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 connection.fyers.__ping()
#
# AttributeError: 'FyersDataSocket' object has no attribute '__ping'

# %%
Main.threadripper(token,True)

# %%
import Backtest
uno = Backtest.SingleavgParser('data/NSE/BAJFINANCE/symbol-2024-12-30.csv','data/NSE/BAJFINANCE/depth-2024-12-30.csv',"NSE:BAJFINANCE")

# %%
uno.signals()
# Out:
# 	prev avg0, current avg:6889
# sell:1
# {'ltp': '6889.75', 'vol_traded_today': '7998.0', 'last_traded_time': '09-18-36', 'price-sell': 6889, 'vol-sell': 164, 'amt-sell': 1129919.0, 'average-sell': 6889, 'sequence-sell': 1, 'cumulative-vol-sell': 164, 'cumulative-amt-sell': 1129919.0, 'price-buy': 0, 'vol-buy': 0, 'amt-buy': 0, 'average-buy': 0, 'sequence-buy': 1, 'cumulative_vol-buy': 0, 'cumulative_amt-buy': 0.0, 'stonk': 'NSE:BAJFINANCE-EQ'}
# entering signal finder
# faq, making polariser element
# made polariser dict
# added_graph_data to :NSE:BAJFINANCEGRAPH
# 	prev avg6889, current avg:6887
# sequence found in cache
# sell:2
# ...

# %%
avg_r = redis.Redis(host = "localhost", port= 6379, db = 2)

[int(float(x[1][b'ltp'])) for x in avg_r.xrevrange("NSE:BAJFINANCE",count=400)]
# Out:
# []

# %%
avg_r.keys()
# Out:
# []

# %%
import datetime as dt 
import time
dt.datetime.strftime(dt.datetime.fromtimestamp(time.time()),'%H-%M-%S')
# Out:
# '10-18-30'
